# %%
! pip install psycopg2-binary
# Out:
# ...
#   Using cached psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Using cached psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import psycopg2

# %%
db = psycopg2.connect(database="core", user='main', password='password', host='127.0.0.1', port=5432)
cursor = db.cursor()

# %%
cursor.execute('select count(*) from bank_operations;')
cursor.fetchone()
# Out:
# (3518,)

# %%
import pandas as pd

df_bank_operations = pd.read_sql('select * from bank_operations;', db, index_col='id')

df_bank_operations.head()
# Out:
#            date  firm_id   main_account_number        account_number  \
# id
# 181  2023-10-25        1  20208000605648493001  16401000005648493001
# 182  2023-10-25        1  20208000605648493001  16401000005648493001
# 912  2024-01-29        1  20208000605648493001  16401000005648493001
# 184  2023-10-25        1  20208000605648493001  23510000205648493001
# 185  2023-10-25        1  20208000605648493001  23510000505648493200
#
#     base_account_number        inn             type    status  \
# id
# 181            05648493  310470638   EXPENSE_OUTPUT  APPROVED
# 182            05648493  310470638   EXPENSE_OUTPUT  APPROVED
# 912            05648493  310470638   EXPENSE_OUTPUT  APPROVED
# 184            05648493  310470638  BANK_INPUT_TYPE  APPROVED
# 185            05648493  310470638  BANK_INPUT_TYPE  APPROVED
#
#                                         firm_name document_number  ...  \
# id                                                                 ...
# ...

# %%
db.close()
