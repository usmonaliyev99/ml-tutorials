# %% [markdown]
# Import numpy library

# %%
import numpy as np

# %%
my_list = list(range(100000))
np_array = np.array(range(100000))

# %%
# %time for _ in range(10): [x * 2 for x in my_list]
# Out:
# CPU times: user 62.5 ms, sys: 9.98 ms, total: 72.5 ms
# Wall time: 73.1 ms

# %%
# %time for _ in range(10): np_array * 2
# Out:
# CPU times: user 2.7 ms, sys: 76 µs, total: 2.77 ms
# Wall time: 2.21 ms

# %%
73.1/2.21
# Out:
# 33.07692307692307
